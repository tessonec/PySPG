# %%
# %matplotlib notebook
# %cd /home/tessonec/devel/PySPG/test-notebook

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/mnt/hgfs/tessonec/Development/PySPG")

from spg.plot.notebook import SPGDataLoader, CSVDataLoader, SPGInteractivePlotter, SPGInteractiveScalingPlotter
# Out:
# /mnt/hgfs/tessonec/Development/PySPG/test-notebook
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sdl = SPGDataLoader("psetting_t3.spg")
# sdl.setup_output_columns(['orph_blc_rate', 'mean_prop_time'])
# Out:
# [__main__.py -   INF ] no 'input' file found: nakamoto_exp.py
# constants: ['max_branch', 'num_branch', 'mean_prop_time', 'orph_blc_rate', 'num_orph_blc', 'num_blocks', 'repetition_time', 'max_prop_time', 'num_onchain_blocks']
# independent variables: ['simulating_days', 'network_topology', 'num_nodes', 'pow_target_spacing', 'expo', 'nodes_conn', 'net_delay']
# output columns: ['max_branch', 'num_branch', 'orph_blc_rate', 'num_blocks', 'num_onchain_blocks', 'num_orph_blc', 'mean_prop_time', 'max_prop_time', 'repetition_time']

# %%
cdl = CSVDataLoader("psetting_t3_results.csv")
cdl.configure_vars(['num_nodes'],['nodes_conn'])
#cdl.setup_output_columns(['orph_blc_rate','mean_prop_time'])
# Out:
# constants: ['simulating_days', 'pow_target_spacing', 'expo', 'network_topology']
# independent variables: ['num_nodes', 'nodes_conn', 'net_delay', 'max_branch', 'num_branch', 'orph_blc_rate', 'num_blocks', 'num_onchain_blocks', 'num_orph_blc', 'mean_prop_time', 'max_prop_time', 'repetition_time']
# output columns: []

# %%
isp = SPGInteractiveScalingPlotter(cdl)

# %%
isp.add_scaling_parameter('alpha',1.0)
isp.add_scaling_parameter('beta',2.0)
isp.setup_transforms("{net_delay}/{alpha}","{orph_blc_rate}**{beta}/{net_delay}")
isp.interact()
# Out:
# <img src="data:image/png;base64,...">
